# %% [markdown]
# # Approach 1: Random Fuzzing on Model 1

# %%
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random, os
import h5py
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Random Fuzzing

# %% [markdown]
# At an initial stage, we have to iteratively apply Random Fuzzing for one image and observe the number of pixels
# at which model starts to give us wrong prediction. An image of label 2 (Sign- 50km/hr) has been chosen.

# %%
def grayscale(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return img

def equalize(img):
    img = cv2.equalizeHist(img)
    return img

def preprocessing(img):
    img = grayscale(img)
    img = equalize(img)
  #normalize the images, i.e. convert the pixel values to fit btwn 0 and 1
    img = img/255
    return img


img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
original_img=img
plt.imshow(img)
plt.title("Original Image (Label-2)")
# Out:
# Text(0.5, 1.0, 'Original Image (Label-2)')

# %% [markdown]
# Step 1: Manipulating random 20 pixels and checking the strength of the model.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,20,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,20,1):
    img[li_x[i]:li_x[i]+1,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)

plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Model is predicting the correct label.
#
# Step 2: Manipulating random 40 pixels and checking the strength of the model.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,40,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,40,1):
    img[li_x[i]:li_x[i]+1,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)

plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Model is predicting the right label.
#
# Step 3: Manipulating random 60 pixels

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,60,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,60,1):
    img[li_x[i]:li_x[i]+1,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)

plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# The image is recognizable by human eye. The model is still predicting the right image.
#
# Step 4: Now observing the strength of the model by manipulating 80 pixels.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,40,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,40,1):
    img[li_x[i]:li_x[i]+2,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)

plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Step 5: Checking for 100 pixels by choosing 50 random points. The length of the x-axis of the pixel is 2 and
# length of the y-axis is 1, so in total 100 pixels are manipulated.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,50,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,50,1):
    img[li_x[i]:li_x[i]+2,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Step 6: Checking for 120 pixels by choosing 60 random points. The length of the x-axis of the pixel is 2 and
# length of the y-axis is 1, so in total 120 pixels are manipulated.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,60,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,60,1):
    img[li_x[i]:li_x[i]+2,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Step 7: Checking for 140 pixels by choosing 70 random points. The length of the x-axis of the pixel is 2 and
# length of the y-axis is 1, so in total 140 pixels are manipulated.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,70,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,70,1):
    img[li_x[i]:li_x[i]+2,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Step 8: Checking for 160 pixels by choosing 80 random points. The length of the x-axis of the pixel is 2 and
# length of the y-axis is 1, so in total 160 pixels are manipulated.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,80,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,80,1):
    img[li_x[i]:li_x[i]+2,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Step 9: Checking for 180 pixels by choosing 90 random points. The length of the x-axis of the pixel is 2 and
# length of the y-axis is 1, so in total 180 pixels are manipulated.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,90,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,90,1):
    img[li_x[i]:li_x[i]+2,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Step 10: Checking for 200 pixels by choosing 50 random points. The length of the x-axis of the pixel is 4 and
# length of the y-axis is 1, so in total 200 pixels are manipulated.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,50,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,50,1):
    img[li_x[i]:li_x[i]+4,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Step 11: Checking for 240 pixels by choosing 60 random points. The length of the x-axis of the pixel is 4 and
# length of the y-axis is 1, so in total 240 pixels are manipulated.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,60,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,60,1):
    img[li_x[i]:li_x[i]+4,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[2]')

# %% [markdown]
# Step 12: Checking for 280 pixels by choosing 70 random points. The length of the x-axis of the pixel is 4 and
# length of the y-axis is 1, so in total 280 pixels are manipulated.

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,70,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,70,1):
    img[li_x[i]:li_x[i]+4,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Label-[40]')

# %% [markdown]
# Finally the model is predicting a wrong label. In order to test how much is the drop in accuracy after
# manipulating, we will be manipulating 200 images and we will test the model on it.

# %% [markdown]
# # Examples of Random Fuzzing

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
original_img=img
plt.imshow(img)
plt.title("Original Image (Label-2)")
# Out:
# Text(0.5, 1.0, 'Original Image (Label-2)')

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00002/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,70,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,70,1):
    img[li_x[i]:li_x[i]+4,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Image after Random Fuzzing, Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Image after Random Fuzzing, Label-[3]')

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00005/00016_00018.ppm"
img=cv2.imread(img)
original_img=img
plt.imshow(img)
plt.title("Original Image (Label-1)")
# Out:
# Text(0.5, 1.0, 'Original Image (Label-1)')

# %%
img="/home/pulkit/Downloads/GTSRB/Training/00005/00016_00018.ppm"
img=cv2.imread(img)
li_x=[]
li_y=[]
for i in range(0,70,1):  
    li_x.append(random.randint(0,40))
    li_y.append(random.randint(0,40))
for i in range(0,70,1):
    img[li_x[i]:li_x[i]+4,li_y[i]:li_y[i]+1] = (255,255,255)

plt.imshow(img)
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
img = img.reshape(1, 32, 32, 1)

model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
model.predict_classes(img)
plt.title("Image after Random Fuzzing, Label-"+str(model.predict_classes(img)))
# Out:
# Text(0.5, 1.0, 'Image after Random Fuzzing, Label-[2]')

# %% [markdown]
# We can clearly see that, the quality of the image is degraded.

# %% [markdown]
# # Testing on 200 images

# %% [markdown]
# At this step we will define two functions- choose_folder() and image_path() which heps us by, taking two
# random images from the dataset and testing it.

# %%
def choose_folder():
    folder_label=["00001","00002","00003","00004","00005","00006","00007",
                   "00008","00009","00010","00011","00012","00013","00014",
                    "00015","00016","00017","00018","00019","00020","00021",
                     "00022","00023","00024","00025","00026","00027","00028",
                     "00029","00030","00031","00032","00033","00034","00035",
                      "00036","00037","00038","00039","00040","00041","00042"]
    
    folder=random.choice(folder_label)
    return folder


def image_path():
    folder=choose_folder()
    print("****************************************************************************")
    print("the True Label is",int(folder))
    path = r"/home/pulkit/Downloads/GTSRB/Training/"
    path=path+folder+"/"
    #print("the path is ",path)
    my_image = random.choice([
    x for x in os.listdir(path)
    if os.path.isfile(os.path.join(path, x))
    ])
    p=os.path.join(path, my_image)
    return p,folder

# %% [markdown]
# At this step, we will define the fuctions which will be important to process the image.

# %%
def grayscale(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return img

def equalize(img):
    img = cv2.equalizeHist(img)
    return img

def preprocessing(img):
    img = grayscale(img)
    img = equalize(img)
  #normalize the images, i.e. convert the pixel values to fit btwn 0 and 1
    img = img/255
    return img

# %% [markdown]
# At this step, we will define a fuction random_fuzzing_model_1, which will load the image, model, manipulate
# random 280 pixels and check the accuracy of the model on the manipulated images.

# %%
def random_fuzzing_model_1():
    model = load_model('/home/pulkit/Desktop/Traffic-Sign-Classification/my_model.h5')
    y_true=[]
    y_pred=[]
    
    for i in range(0,200,1):
        li_x=[]
        li_y=[]
        for i in range(0,70,1):  
            
            li_x.append(random.randint(0,40))
            li_y.append(random.randint(0,40))
           

    
        # loading the image
        path,label=image_path()
        y_true.append(int(label))
        img = cv2.imread(path,1)
        
        # manipulating random pixels (70 * 4 =280 pixels manipulated in 70 iterations on image)
        for i in range(0,70,1):
            
            img[li_x[i]:li_x[i]+4,li_y[i]:li_y[i]+1] = (255,255,255)

        #img = cv2.bilateralFilter(img,9,75,75)
        
        # preprocessing the image so that it can be given an input to the model
        img = np.asarray(img)
        img = cv2.resize(img, (32, 32))
        img = preprocessing(img)
        img = img.reshape(1, 32, 32, 1)


        pred=int(model.predict_classes(img))
        y_pred.append(pred)
        
        print("The Predicted label is "+ str(model.predict_classes(img)))
       
    # getting the accuracy score
    
    print("****************************************************************************")
    correct_percent=accuracy_score(y_true, y_pred)
    print(correct_percent)

# %%
random_fuzzing_model_1()
# Out:
# ****************************************************************************
# the True Label is 00011
# The Predicted label is [12]
# ****************************************************************************
# the True Label is 00006
# The Predicted label is [6]
# ****************************************************************************
# the True Label is 00017
# The Predicted label is [28]
# ****************************************************************************
# the True Label is 00024
# The Predicted label is [24]
# ****************************************************************************
# the True Label is 00038
# The Predicted label is [13]
# ****************************************************************************
# the True Label is 00033
# The Predicted label is [33]
# ****************************************************************************
# the True Label is 00039
# The Predicted label is [39]
# ...

# %% [markdown]
# Conclusion-: Applying Random Fuzzing decreases the prediction accuracy of the model from 99% to 54%.
# In order to further decresase the the prediction accuracy, we can apply the Random Fuzzing by manipulating
# more pixels. Further applying Random Fuzzing on the image will make the quality of the image so bad, that
# even the human eye will not be able to recognize it.
#
# Note-: The quality of the image obtained after FGSM attack, is far superior than obtained by Random Fuzzing.
